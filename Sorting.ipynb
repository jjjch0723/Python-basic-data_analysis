# %%
import csv

f = open('Seoul.csv','r',encoding='utf8')
data = csv.reader(f)

header = next(data) #맨윗쪽 제거

#데이터를 저장하기 이ㅜ한 리스트 제작
temp = []
count = 1

firstRow = next(data)
min_temp = firstRow[-2]
min_temp = float(min_temp)
temp.append(row[-2])

for row in data:
    if row[-2] == '':
        row[-2] = 0

    row[-2] = float(row[-2])
    if count < 100:
        temp.append(row[-2])
    count += 1
    if min_temp > row[-2]:
        min_temp = row[-2]
        min_data = row[0]
     
print('최저기온은 ',min_data,)
print(len(temp))
# Out:
# 최저기온은  Dec-27
# 100

# %%
import matplotlib.pyplot as plt
'''
x_data = [2, 7, 12, 16, 23]
y_data = [10, 15, 20, 56, 70]
'''
plt.title('temp of Seoul')
plt.plot(temp, color='red', marker='.', table='temp')
plt.legend()
plt.figure(figsize(10,2))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [38], in <cell line: 7>()
#       2 '''
#       3 x_data = [2, 7, 12, 16, 23]
#       4 y_data = [10, 15, 20, 56, 70]
#       5 '''
#       6 plt.title('temp of Seoul')
# ----> 7 plt.plot(temp, color='red', marker='.', table='temp')
#       8 plt.plot(temp)
#       9 plt.show()
#
# File ~\Anaconda\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
# ...

# %%
import csv
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 2))

f = open('seoul.csv','r', encoding='utf8')
data = csv.reader(f)
header = next(data)
result = []
count = 0
for row in data :
    count += 1
    if count <= 100 :
        result.append(float(row[-1]))
        

plt.title('temp of Seoul')
plt.plot(result, color='red', marker='.', label='temp')
plt.show()
